# %%
# ==============================
# STEP 1: Import All Libraries
# ==============================

# Data handling
import pandas as pd
import numpy as np

# Visualization (EDA)
import matplotlib.pyplot as plt
import seaborn as sns

# Interactive visualization (Dashboard)
import plotly.express as px
import plotly.io as pio

# Set plot styles
sns.set(style="whitegrid")
pio.renderers.default = "notebook"

print("All libraries imported successfully!")
# Out:
# All libraries imported successfully!

# %%
# ==============================
# STEP 2: Define Paths
# ==============================

base_path = "C:/Users/Varnika Sharma/Desktop/Crime Analysis/Crime Analysis/01_Data/Cleaned_Dataset/"

ipc_path = base_path + "IPC_CRIMES/"
women_path = base_path + "WOMEN_CRIMES/"
children_path = base_path + "CHILDREN_CRIMES/"
cyber_path = base_path + "CYBER_CRIMES/"

print("Paths set successfully!")
# Out:
# Paths set successfully!

# %%
# ==============================
# STEP 3: Universal Processing Function
# ==============================

def process_dataset(file_path, year, dataset_name):
    df = pd.read_excel(file_path)

    # Clean column names
    df.columns = df.columns.str.strip()

    # Handle State column variations
    if "State/UT" in df.columns:
        df.rename(columns={"State/UT": "State"}, inplace=True)
    elif "STATE/UT" in df.columns:
        df.rename(columns={"STATE/UT": "State"}, inplace=True)
    elif "State" not in df.columns:
        df.rename(columns={df.columns[1]: "State"}, inplace=True)

    # Drop serial column if exists
    if "SL" in df.columns:
        df.drop(columns=["SL"], inplace=True)

    # Convert wide → long
    df_long = pd.melt(
        df,
        id_vars=["State"],
        var_name="Crime_Info",
        value_name="Value"
    )

    # Split Crime_Info into parts
    df_long[["Category", "Crime", "Metric"]] = df_long["Crime_Info"].str.rsplit("_", n=2, expand=True)

    # Clean values
    df_long["Value"] = pd.to_numeric(df_long["Value"], errors="coerce")
    df_long.dropna(inplace=True)

    # Remove totals (very important)
    df_long = df_long[~df_long["Crime"].str.contains("total|all", case=False, na=False)]

    # Add metadata
    df_long["Year"] = year
    df_long["Dataset"] = dataset_name

    print(f"{dataset_name} {year} processed successfully. Shape:", df_long.shape)

    return df_long

# %%
# ==============================
# STEP 4: Load Datasets (2021)
# ==============================

ipc_2021 = process_dataset(ipc_path + "IPC_Crimes_Head-wise_Raw_2021.xlsx", 2021, "IPC")
women_2021 = process_dataset(women_path + "Crimes_Against_Women_Head-wise_State-UT_Raw_2021.xlsx", 2021, "Women")
children_2021 = process_dataset(children_path + "Crimes_Against_Children_State-UT_2021.xlsx", 2021, "Children")
cyber_2021 = process_dataset(cyber_path + "Cyber_Crimes_State-UT_2021.xlsx", 2021, "Cyber")
# Out:
# IPC 2021 processed successfully. Shape: (12816, 8)
# Women 2021 processed successfully. Shape: (4572, 8)
# Children 2021 processed successfully. Shape: (5976, 8)
# Cyber 2021 processed successfully. Shape: (1548, 8)

# %%
# ==============================
# STEP 5: Combine Datasets
# ==============================

final_df = pd.concat(
    [ipc_2021, women_2021, children_2021, cyber_2021],
    ignore_index=True
)

print("Final dataset shape:", final_df.shape)
display(final_df.head())
# Out:
# Final dataset shape: (24912, 8)
#                State                                         Crime_Info  \
# 0     Andhra Pradesh  Offences affecting the Human Body_Murder (Sec....
# 1  Arunachal Pradesh  Offences affecting the Human Body_Murder (Sec....
# 2              Assam  Offences affecting the Human Body_Murder (Sec....
# 3              Bihar  Offences affecting the Human Body_Murder (Sec....
# 4       Chhattisgarh  Offences affecting the Human Body_Murder (Sec....
#
#     Value                                           Category Crime Metric  \
# 0   956.0  Offences affecting the Human Body_Murder (Sec....            I
# 1    49.0  Offences affecting the Human Body_Murder (Sec....            I
# 2  1192.0  Offences affecting the Human Body_Murder (Sec....            I
# 3  2799.0  Offences affecting the Human Body_Murder (Sec....            I
# 4  1007.0  Offences affecting the Human Body_Murder (Sec....            I
#
#    Year Dataset
# 0  2021     IPC
# 1  2021     IPC
# 2  2021     IPC
# 3  2021     IPC
# 4  2021     IPC

# %%
print(final_df["Dataset"].value_counts())
print(final_df["Year"].value_counts())
# Out:
# Dataset
# IPC         12816
# Children     5976
# Women        4572
# Cyber        1548
# Name: count, dtype: int64
# Year
# 2021    24912
# Name: count, dtype: int64

# %%
# ==============================
# STEP 6: Load Datasets (All Years)
# ==============================

# ---- 2021 ----
ipc_2021 = process_dataset(ipc_path + "IPC_Crimes_Head-wise_Raw_2021.xlsx", 2021, "IPC")
women_2021 = process_dataset(women_path + "Crimes_Against_Women_Head-wise_State-UT_Raw_2021.xlsx", 2021, "Women")
children_2021 = process_dataset(children_path + "Crimes_Against_Children_State-UT_2021.xlsx", 2021, "Children")
cyber_2021 = process_dataset(cyber_path + "Cyber_Crimes_State-UT_2021.xlsx", 2021, "Cyber")

# ---- 2022 ----
ipc_2022 = process_dataset(ipc_path + "IPC_Crimes_Head-wise_Raw_2022.xlsx", 2022, "IPC")
women_2022 = process_dataset(women_path + "Crimes_Against_Women_Head-wise_State-UT_Raw_2021.xlsx", 2022, "Women")
children_2022 = process_dataset(children_path + "Crimes_Against_Children_State-UT_2021.xlsx", 2022, "Children")
cyber_2022 = process_dataset(cyber_path + "Cyber_Crimes_State-UT_2021.xlsx", 2022, "Cyber")

# ---- 2023 ----
ipc_2023 = process_dataset(ipc_path + "IPC_Crimes_Head-wise_Raw_2023.xlsx", 2023, "IPC")
women_2023 = process_dataset(women_path + "Crimes_Against_Women_Head-wise_State-UT_Raw_2021.xlsx", 2023, "Women")
children_2023 = process_dataset(children_path + "Crimes_Against_Children_State-UT_2021.xlsx", 2023, "Children")
cyber_2023 = process_dataset(cyber_path + "Cyber_Crimes_State-UT_2021.xlsx", 2023, "Cyber")
# Out:
# IPC 2021 processed successfully. Shape: (12816, 8)
# Women 2021 processed successfully. Shape: (4572, 8)
# Children 2021 processed successfully. Shape: (5976, 8)
# Cyber 2021 processed successfully. Shape: (1548, 8)
# IPC 2022 processed successfully. Shape: (12816, 8)
# Women 2022 processed successfully. Shape: (4572, 8)
# Children 2022 processed successfully. Shape: (5976, 8)
# Cyber 2022 processed successfully. Shape: (1548, 8)
# IPC 2023 processed successfully. Shape: (12816, 8)
# Women 2023 processed successfully. Shape: (4572, 8)
# Children 2023 processed successfully. Shape: (5976, 8)
# Cyber 2023 processed successfully. Shape: (1548, 8)

# %%
# Shorten crime names (remove sections and long text)
ipc_long["Crime"] = ipc_long["Crime"].str.replace(r".∗?.*?", "", regex=True)  # remove (Sec...)
ipc_long["Crime"] = ipc_long["Crime"].str.replace("  ", " ")
ipc_long["Crime"] = ipc_long["Crime"].str.strip()

# %%
top_crimes = (
    ipc_long[ipc_long["Metric"] == "I"]
    .groupby("Crime")["Value"]
    .sum()
    .sort_values(ascending=False)
    .head(10)
)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))  # wider plot

top_crimes.plot(kind='bar')

plt.title("Top 10 Crimes in India (2021)", fontsize=14)
plt.ylabel("Number of Cases")
plt.xlabel("Crime Type")

plt.xticks(rotation=30, ha='right')  # less tilt, better readability
plt.tight_layout()

plt.show()

# %%
# Save final dataset
ipc_long.to_csv("C:/Users/Varnika Sharma/Desktop/Crime Analysis/Crime Analysis/01_Data/Final_Dataset/ipc_final_2021.csv", index=False)

print("Dataset saved successfully!")

# %%
# ============================================
# FIXED FUNCTION (handles column issues)
# ============================================

def process_dataset(file_path, year, dataset_name):
    df = pd.read_excel(file_path)

    df.columns = df.columns.str.strip()

    # Handle State column
    if "State/UT" in df.columns:
        df.rename(columns={"State/UT": "State"}, inplace=True)
    elif "STATE/UT" in df.columns:
        df.rename(columns={"STATE/UT": "State"}, inplace=True)
    elif "State" not in df.columns:
        df.rename(columns={df.columns[1]: "State"}, inplace=True)

    # Drop unwanted
    if "SL" in df.columns:
        df.drop(columns=["SL"], inplace=True)

    # Melt
    df_long = pd.melt(
        df,
        id_vars=["State"],
        var_name="Crime_Info",
        value_name="Value"
    )

    # Split
    df_long[["Category", "Crime", "Metric"]] = df_long["Crime_Info"].str.rsplit("_", n=2, expand=True)

    # Clean
    df_long["Value"] = pd.to_numeric(df_long["Value"], errors="coerce")
    df_long.dropna(inplace=True)

    # Remove totals (IMPORTANT FIX)
    df_long = df_long[~df_long["Crime"].str.contains("total|all", case=False, na=False)]

    # Add columns
    df_long["Year"] = year
    df_long["Dataset"] = dataset_name

    return df_long

# %%
# ============================================
# STEP 12: Process all datasets
# ============================================
ipc_2021=process_dataset("C:/Users/Varnika Sharma/Desktop/Crime Analysis/Crime Analysis/01_Data/Cleaned_Dataset/IPC_CRIMES/IPC_Crimes_Head-wise_Raw_2021.xlsx", 2021, ipc)
women_2021 = process_dataset("C:/Users/Varnika Sharma/Desktop/Crime Analysis/Crime Analysis/01_Data/Cleaned_Dataset/WOMEN_CRIMES/Crimes_Against_Women_Head-wise_State-UT_Raw_2021.xlsx", 2021, Women)
children_2021 = process_dataset("C:/Users/Varnika Sharma/Desktop/Crime Analysis/Crime Analysis/01_Data/Cleaned_Dataset/CHILDREN_CRIMES/Crimes_Against_Children_State-UT_2021.xlsx", 2021, Children)
cyber_2021 = process_dataset("C:/Users/Varnika Sharma/Desktop/Crime Analysis/Crime Analysis/01_Data/Cleaned_Dataset/CYBER_CRIMES/Cyber_Crimes_State-UT_2021.xlsx", 2021, Cyber)

print("Women dataset shape:", women_2021.shape)
print("Children dataset shape:", children_2021.shape)
print("Cyber dataset shape:", cyber_2021.shape)

# %%
# ============================================
# STEP 13: Combine all datasets
# ============================================

final_df = pd.concat([ipc_long, women_2021, children_2021, cyber_2021])

print("Final combined dataset shape:")
print(final_df.shape)

display(final_df.head())

# %%
import plotly.express as px
import plotly.io as pio
pio.renderers.default = "notebook"
# Filter only Incidence
df_plot = final_df[
    (final_df["Metric"] == "I") &
    (~final_df["Crime"].str.contains("Total", case=False, na=False)) &
    (~final_df["Crime"].str.contains("All", case=False, na=False))
]

top_crimes = (
    df_plot.groupby("Crime")["Value"]
    .sum()
    .sort_values(ascending=False)
    .head(10)
    .reset_index()
)
top_crimes = (
    df_plot.groupby("Crime")["Value"]
    .sum()
    .sort_values(ascending=False)
    .head(10)
    .reset_index()
)

fig = px.bar(
    top_crimes,
    x="Crime",
    y="Value",
    title="Top 10 Crimes in India (2021)",
)

fig.show()
