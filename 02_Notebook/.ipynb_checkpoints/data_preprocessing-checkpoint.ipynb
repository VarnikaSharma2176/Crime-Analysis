# %%
# Install plotly (only needed once)
# !pip install plotly
# Out:
# ...
# WARNING: Ignoring invalid distribution ~ip (C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages)
#
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# ============================================
# STEP 1: Import Required Libraries
# ============================================

# pandas → used for handling data (like Excel but more powerful)
import pandas as pd

# numpy → used for numerical operations
import numpy as np

# matplotlib → basic plotting (used later for EDA)
import matplotlib.pyplot as plt

# seaborn → advanced plotting (used later for better visuals)
import seaborn as sns

# plotly → interactive visualizations (used for dashboard later)
import plotly.express as px

# %%
# ============================================
# STEP 3: Load IPC 2021 Dataset
# ============================================

# Load the Excel file into a pandas DataFrame
ipc_2021 = pd.read_excel("C:/Users/Varnika Sharma/Desktop/Crime Analysis/Crime Analysis/01_Data/Raw_Dataset/IPC_CRIMES/IPC_Crimes_Head-wise_Raw_2021.xlsx")

# Display first 5 rows to understand structure
ipc_2021.head()
# Out:
#     SL        State/UT Offences affecting the Human Body  \
# 0  NaN             NaN              Murder (Sec.302 IPC)
# 1  NaN             NaN                               NaN
# 2  NaN             NaN                               NaN
# 3  NaN             NaN                                 I
# 4  1.0  Andhra Pradesh                               956
#
#   Offences affecting the Human Body.1 Offences affecting the Human Body.2  \
# 0                Murder (Sec.302 IPC)                Murder (Sec.302 IPC)
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                   V                                   R
# 4                                 985                                 1.8
#
#                  Offences affecting the Human Body.3  \
# 0  Culpable Homicide not Amounting to Murder (Sec...
# 1                                                NaN
# ...

# %%
# ============================================
# STEP 4: Load IPC 2021 Dataset (Clean Way)
# ============================================

# We skip the first few rows because they contain titles and merged headers
ipc_2021 = pd.read_excel(
    "C:/Users/Varnika Sharma/Desktop/Crime Analysis/Crime Analysis/01_Data/Raw_Dataset/IPC_CRIMES/IPC_Crimes_Head-wise_Raw_2021.xlsx",
    skiprows=6   # <-- this is the key fix
)

# Preview the cleaned structure
ipc_2021.head()
# Out:
#    2 Arunachal Pradesh    49    54  3.2    3  3.1  0.2    40    48  ...  \
# 0  3             Assam  1192  1269  3.4   95   96  0.3  1475  1534  ...
# 1  4             Bihar  2799  2826  2.3  136  140  0.1  1039  1097  ...
# 2  5      Chhattisgarh  1007  1057  3.4   42   42  0.1  1777  1939  ...
# 3  6               Goa    26    28  1.7    2    2  0.1    23    23  ...
# 4  7           Gujarat  1010  1046  1.4  114  235  0.2  1119  1156  ...
#
#    0.166    3.8    3.9  0.2.3   10  10.1  1.3    281    284   18.3
# 0    0.1   1538   1538    4.4  184   194  1.1  14805  14956   42.1
# 1    0.1    319    319    0.3    1     1  0.0    200    187    0.2
# 2    0.0   1989   1995    6.7  238   240  1.6   6273   6392   21.2
# 3    0.0     42     43    2.7   20    20  2.6      6      5    0.4
# 4    0.0  17849  18692   25.5    7     7  0.0  88244  38842  125.9
#
# [5 rows x 358 columns]
