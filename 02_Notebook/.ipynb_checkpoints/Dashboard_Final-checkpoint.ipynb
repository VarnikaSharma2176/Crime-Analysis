# %%
# !pip install streamlit plotly seaborn matplotlib pandas numpy
# Out:
# Collecting streamlit
#   Downloading streamlit-1.56.0-py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: plotly in C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages (6.7.0)
# Requirement already satisfied: seaborn in C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages (0.13.2)
# Requirement already satisfied: matplotlib in C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.10.8)
# Requirement already satisfied: pandas in C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.0.0)
# Requirement already satisfied: numpy in C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages (2.4.2)
# Collecting altair!=5.4.0,!=5.4.1,<7,>=4.0 (from streamlit)
#   Downloading altair-6.1.0-py3-none-any.whl.metadata (11 kB)
# Collecting blinker<2,>=1.5.0 (from streamlit)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<8,>=5.5 (from streamlit)
#   Downloading cachetools-7.0.6-py3-none-any.whl.metadata (5.9 kB)
# Collecting click<9,>=7.0 (from streamlit)
#   Downloading click-8.3.3-py3-none-any.whl.metadata (2.6 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading gitpython-3.1.47-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: packaging>=20 in C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (26.0)
# Requirement already satisfied: pillow<13,>=7.1.0 in C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (12.1.1)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.2-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting protobuf<8,>=3.20 (from streamlit)
#   Downloading protobuf-7.34.1-cp310-abi3-win_amd64.whl.metadata (595 bytes)
# Collecting pyarrow>=7.0 (from streamlit)
#   Downloading pyarrow-24.0.0-cp314-cp314-win_amd64.whl.metadata (3.0 kB)
# Requirement already satisfied: requests<3,>=2.27 in C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (2.32.5)
# Collecting tenacity<10,>=8.1.0 (from streamlit)
#   Downloading tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (6.5.4)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (4.15.0)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Downloading watchdog-6.0.0-py3-none-win_amd64.whl.metadata (44 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: jinja2 in C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=2.4.0 in C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.19.0)
# Requirement already satisfied: colorama in C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests<3,>=2.27->streamlit) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests<3,>=2.27->streamlit) (2026.1.4)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.0)
# Requirement already satisfied: six>=1.5 in C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading streamlit-1.56.0-py3-none-any.whl (9.1 MB)
#    ---------------------------------------- 0.0/9.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.1 MB 2.4 MB/s eta 0:00:04
#    ------ --------------------------------- 1.6/9.1 MB 3.1 MB/s eta 0:00:03
#    ------------- -------------------------- 3.1/9.1 MB 4.6 MB/s eta 0:00:02
#    -------------------- ------------------- 4.7/9.1 MB 5.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.6/9.1 MB 5.9 MB/s eta 0:00:01
#    ------------------------------------- -- 8.4/9.1 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.1/9.1 MB 6.4 MB/s  0:00:01
# Downloading altair-6.1.0-py3-none-any.whl (796 kB)
#    ---------------------------------------- 0.0/797.0 kB ? eta -:--:--
#    ---------------------------------------- 797.0/797.0 kB 7.7 MB/s  0:00:00
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading cachetools-7.0.6-py3-none-any.whl (13 kB)
# Downloading click-8.3.3-py3-none-any.whl (110 kB)
# Downloading gitpython-3.1.47-py3-none-any.whl (209 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading protobuf-7.34.1-cp310-abi3-win_amd64.whl (437 kB)
# Downloading pydeck-0.9.2-py2.py3-none-any.whl (11.3 MB)
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ------ --------------------------------- 1.8/11.3 MB 8.5 MB/s eta 0:00:02
#    ------------ --------------------------- 3.7/11.3 MB 9.0 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.0/11.3 MB 8.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.6/11.3 MB 8.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.6/11.3 MB 8.0 MB/s eta 0:00:01
#    -------------------------------------- - 10.7/11.3 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.3 MB 7.8 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 7.6 MB/s  0:00:01
# Downloading smmap-5.0.3-py3-none-any.whl (24 kB)
# Downloading tenacity-9.1.4-py3-none-any.whl (28 kB)
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading watchdog-6.0.0-py3-none-win_amd64.whl (79 kB)
# Downloading pyarrow-24.0.0-cp314-cp314-win_amd64.whl (28.0 MB)
#    ---------------------------------------- 0.0/28.0 MB ? eta -:--:--
#    -- ------------------------------------- 1.8/28.0 MB 8.2 MB/s eta 0:00:04
#    ---- ----------------------------------- 3.4/28.0 MB 8.3 MB/s eta 0:00:03
#    ------ --------------------------------- 4.7/28.0 MB 7.6 MB/s eta 0:00:04
#    --------- ------------------------------ 6.6/28.0 MB 7.8 MB/s eta 0:00:03
#    ----------- ---------------------------- 8.1/28.0 MB 7.9 MB/s eta 0:00:03
#    -------------- ------------------------- 10.2/28.0 MB 8.0 MB/s eta 0:00:03
#    ----------------- ---------------------- 12.3/28.0 MB 8.3 MB/s eta 0:00:02
#    ------------------ --------------------- 13.1/28.0 MB 7.7 MB/s eta 0:00:02
#    -------------------- ------------------- 14.2/28.0 MB 7.4 MB/s eta 0:00:02
#    --------------------- ------------------ 15.2/28.0 MB 7.2 MB/s eta 0:00:02
#    ----------------------- ---------------- 16.5/28.0 MB 7.1 MB/s eta 0:00:02
#    ------------------------- -------------- 18.1/28.0 MB 7.2 MB/s eta 0:00:02
#    --------------------------- ------------ 19.1/28.0 MB 7.0 MB/s eta 0:00:02
#    ----------------------------- ---------- 20.7/28.0 MB 7.0 MB/s eta 0:00:02
#    ------------------------------ --------- 21.5/28.0 MB 6.8 MB/s eta 0:00:01
#    --------------------------------- ------ 23.3/28.0 MB 6.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 24.6/28.0 MB 6.9 MB/s eta 0:00:01
#    ------------------------------------- -- 26.5/28.0 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------  27.8/28.0 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 28.0/28.0 MB 6.8 MB/s  0:00:04
# Installing collected packages: watchdog, toml, tenacity, smmap, pyarrow, protobuf, click, cachetools, blinker, pydeck, gitdb, gitpython, altair, streamlit
#
#    ----------------------------------------  0/14 [watchdog]
#    ----------------------------------------  0/14 [watchdog]
#    ----------------------------------------  0/14 [watchdog]
#    ----------------------------------------  0/14 [watchdog]
#    ----------------------------------------  0/14 [watchdog]
#    -- -------------------------------------  1/14 [toml]
#    ----- ----------------------------------  2/14 [tenacity]
#    ----- ----------------------------------  2/14 [tenacity]
#    ----- ----------------------------------  2/14 [tenacity]
#    -------- -------------------------------  3/14 [smmap]
#    ----------- ----------------------------  4/14 [pyarrow]
#    ----------- ----------------------------  4/14 [pyarrow]
#    ----------- ----------------------------  4/14 [pyarrow]
#    ----------- ----------------------------  4/14 [pyarrow]
#    ----------- ----------------------------  4/14 [pyarrow]
#    ----------- ----------------------------  4/14 [pyarrow]
#    ----------- ----------------------------  4/14 [pyarrow]
#    ----------- ----------------------------  4/14 [pyarrow]
#    ----------- ----------------------------  4/14 [pyarrow]
#    ----------- ----------------------------  4/14 [pyarrow]
#    ----------- ----------------------------  4/14 [pyarrow]
#    ----------- ----------------------------  4/14 [pyarrow]
#    ----------- ----------------------------  4/14 [pyarrow]
#    ----------- ----------------------------  4/14 [pyarrow]
#    ----------- ----------------------------  4/14 [pyarrow]
#    ----------- ----------------------------  4/14 [pyarrow]
#    ----------- ----------------------------  4/14 [pyarrow]
#    ----------- ----------------------------  4/14 [pyarrow]
#    ----------- ----------------------------  4/14 [pyarrow]
#    ----------- ----------------------------  4/14 [pyarrow]
#    ----------- ----------------------------  4/14 [pyarrow]
#    ----------- ----------------------------  4/14 [pyarrow]
#    ----------- ----------------------------  4/14 [pyarrow]
#    ----------- ----------------------------  4/14 [pyarrow]
#    ----------- ----------------------------  4/14 [pyarrow]
#    ----------- ----------------------------  4/14 [pyarrow]
#    ----------- ----------------------------  4/14 [pyarrow]
#    ----------- ----------------------------  4/14 [pyarrow]
#    ----------- ----------------------------  4/14 [pyarrow]
#    ----------- ----------------------------  4/14 [pyarrow]
#    ----------- ----------------------------  4/14 [pyarrow]
#    ----------- ----------------------------  4/14 [pyarrow]
#    -------------- -------------------------  5/14 [protobuf]
#    -------------- -------------------------  5/14 [protobuf]
#    -------------- -------------------------  5/14 [protobuf]
#    -------------- -------------------------  5/14 [protobuf]
#    -------------- -------------------------  5/14 [protobuf]
#    -------------- -------------------------  5/14 [protobuf]
#    -------------- -------------------------  5/14 [protobuf]
#    -------------- -------------------------  5/14 [protobuf]
#    -------------- -------------------------  5/14 [protobuf]
#    -------------- -------------------------  5/14 [protobuf]
#    -------------- -------------------------  5/14 [protobuf]
#    -------------- -------------------------  5/14 [protobuf]
#    ----------------- ----------------------  6/14 [click]
#    ----------------- ----------------------  6/14 [click]
#    ----------------- ----------------------  6/14 [click]
#    ----------------- ----------------------  6/14 [click]
#    -------------------- -------------------  7/14 [cachetools]
#    ------------------------- --------------  9/14 [pydeck]
#    ------------------------- --------------  9/14 [pydeck]
#    ------------------------- --------------  9/14 [pydeck]
#    ------------------------- --------------  9/14 [pydeck]
#    ------------------------- --------------  9/14 [pydeck]
#    ------------------------- --------------  9/14 [pydeck]
#    ------------------------- --------------  9/14 [pydeck]
#    ---------------------------- ----------- 10/14 [gitdb]
#    ---------------------------- ----------- 10/14 [gitdb]
#    ---------------------------- ----------- 10/14 [gitdb]
#    ---------------------------- ----------- 10/14 [gitdb]
#    ------------------------------- -------- 11/14 [gitpython]
#    ------------------------------- -------- 11/14 [gitpython]
#    ------------------------------- -------- 11/14 [gitpython]
#    ------------------------------- -------- 11/14 [gitpython]
#    ------------------------------- -------- 11/14 [gitpython]
#    ------------------------------- -------- 11/14 [gitpython]
#    ------------------------------- -------- 11/14 [gitpython]
#    ------------------------------- -------- 11/14 [gitpython]
#    ---------------------------------- ----- 12/14 [altair]
#    ---------------------------------- ----- 12/14 [altair]
#    ---------------------------------- ----- 12/14 [altair]
#    ---------------------------------- ----- 12/14 [altair]
#    ---------------------------------- ----- 12/14 [altair]
#    ---------------------------------- ----- 12/14 [altair]
#    ---------------------------------- ----- 12/14 [altair]
#    ---------------------------------- ----- 12/14 [altair]
#    ---------------------------------- ----- 12/14 [altair]
#    ---------------------------------- ----- 12/14 [altair]
#    ---------------------------------- ----- 12/14 [altair]
#    ---------------------------------- ----- 12/14 [altair]
#    ---------------------------------- ----- 12/14 [altair]
#    ---------------------------------- ----- 12/14 [altair]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ------------------------------------- -- 13/14 [streamlit]
#    ---------------------------------------- 14/14 [streamlit]
#
# Successfully installed altair-6.1.0 blinker-1.9.0 cachetools-7.0.6 click-8.3.3 gitdb-4.0.12 gitpython-3.1.47 protobuf-7.34.1 pyarrow-24.0.0 pydeck-0.9.2 smmap-5.0.3 streamlit-1.56.0 tenacity-9.1.4 toml-0.10.2 watchdog-6.0.0
# WARNING: Ignoring invalid distribution ~ip (C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages)
#
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# ==============================
# INSTALL (run once if needed)
# ==============================
# !pip install panel hvplot pandas plotly numpy

import pandas as pd
import numpy as np
import panel as pn
import hvplot.pandas
import plotly.express as px

pn.extension('plotly')

# ==============================
# LOAD DATA
# ==============================
df = pd.read_csv("C:/Users/Varnika Sharma/Desktop/Crime Analysis/Crime Analysis/01_Data/Final_Dataset/cleaned_crime_data.csv")   # <-- UPDATE PATH

# ==============================
# FILTERS
# ==============================
year_slider = pn.widgets.IntRangeSlider(
    name="Year Range",
    start=int(df["Year"].min()),
    end=int(df["Year"].max()),
    value=(int(df["Year"].min()), int(df["Year"].max()))
)

state_select = pn.widgets.MultiChoice(
    name="Select States",
    options=sorted(df["State"].unique().tolist()),
    value=sorted(df["State"].unique().tolist())[:10]
)

dataset_select = pn.widgets.MultiChoice(
    name="Crime Category",
    options=sorted(df["Dataset"].unique().tolist()),
    value=sorted(df["Dataset"].unique().tolist())
)

# ==============================
# FILTER FUNCTION
# ==============================
def get_data():
    return df[
        (df["Year"].between(*year_slider.value)) &
        (df["State"].isin(state_select.value)) &
        (df["Dataset"].isin(dataset_select.value))
    ]

# ==============================
# 1. SCATTER
# ==============================
def scatter_plot():
    data = get_data()

    pivot = (
        data.groupby(["State", "Dataset"])["Value"]
        .sum()
        .unstack(fill_value=0)
        .reset_index()
    )

    return pivot.hvplot.scatter(
        x="Women",
        y="Cyber",
        size="Children",
        hover_cols=["State"],
        height=350,
        title="Women vs Cyber Crimes"
    )

# ==============================
# 2. STACKED BAR
# ==============================
def stacked_bar():
    data = get_data()

    grouped = (
        data.groupby(["Year", "Dataset"])["Value"]
        .sum()
        .unstack()
        .fillna(0)
    )

    return grouped.hvplot.bar(
        stacked=True,
        height=350,
        title="Crime Distribution Over Years"
    )

# ==============================
# 3. PIE (COLORED)
# ==============================
def pie_chart():
    data = get_data()

    pie_df = (
        data.groupby("Dataset")["Value"]
        .sum()
        .reset_index()
        .sort_values("Value", ascending=False)
        .head(6)
    )

    fig = px.pie(
        pie_df,
        names="Dataset",
        values="Value",
        hole=0.5,
        title="Crime Share Distribution",
        color="Dataset",
        color_discrete_sequence=px.colors.qualitative.Set2
    )

    return pn.pane.Plotly(fig, height=400)

# ==============================
# 4. STATE BAR (COLORED)
# ==============================
def state_bar():
    data = get_data()

    state_df = (
        data.groupby(["State", "Dataset"])["Value"]
        .sum()
        .reset_index()
    )

    fig = px.bar(
        state_df,
        x="State",
        y="Value",
        color="Dataset",
        title="State-wise Crime Distribution",
        color_discrete_sequence=px.colors.qualitative.Set2
    )

    return pn.pane.Plotly(fig, height=400)

# ==============================
# 5. TREND LINE (COLORED)
# ==============================
def trend_line():
    data = get_data()

    trend_df = (
        data.groupby("Year")["Value"]
        .sum()
        .reset_index()
    )

    fig = px.line(
        trend_df,
        x="Year",
        y="Value",
        markers=True,
        title="Year-wise Crime Trend",
        color_discrete_sequence=["#2a9d8f"]   # clean teal
    )

    return pn.pane.Plotly(fig, height=400)

# ==============================
# 6. GROWTH RATE (COLORED)
# ==============================
def growth_chart():
    data = get_data()

    df_year = (
        data.groupby("Year")["Value"]
        .sum()
        .reset_index()
    )

    df_year["Growth"] = df_year["Value"].pct_change() * 100
    df_year = df_year.dropna()

    fig = px.bar(
        df_year,
        x="Year",
        y="Growth",
        title="Year-wise Crime Growth Rate (%)",
        color="Growth",
        color_continuous_scale="RdYlGn"
    )

    return pn.pane.Plotly(fig, height=400)

# ==============================
# BIND
# ==============================
scatter_p = pn.bind(scatter_plot)
bar_p = pn.bind(stacked_bar)
pie_p = pn.bind(pie_chart)
state_p = pn.bind(state_bar)
trend_p = pn.bind(trend_line)
growth_p = pn.bind(growth_chart)

# ==============================
# DASHBOARD
# ==============================
dashboard = pn.template.FastListTemplate(
    title="Crime Analysis Dashboard (India)",

    sidebar=[
        pn.pane.Markdown("## Filters"),
        year_slider,
        state_select,
        dataset_select
    ],

    main=[
        pn.pane.Markdown("## Overview"),

        pn.Row(scatter_p, bar_p),

        pn.Row(pie_p, state_p),

        pn.Row(trend_p, growth_p)
    ]
)

# ==============================
# RUN
# ==============================
dashboard.show()
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='186758f4-a6c5-4cdf-abec-b22526842898'>
#   <div id="a1a375a3-b54e-4c9f-82e3-65ac905fe045" data-root-id="186758f4-a6c5-4cdf-abec-b22526842898" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"148219ff-823c-4f74-95ad-981580385bfc":{"version":"3.9.0","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"64912a75-9b92-42f7-9a8f-4ef8abafda8f","attributes":{"notifications":{"type":"object","name":"Notifications","id":"78dfc7a9-4920-4921-a76e-a138f11ad9f2"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"186758f4-a6c5-4cdf-abec-b22526842898"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"842b5e65-f373-46eb-b1fd-6067def61218","attributes":{"plot_id":"186758f4-a6c5-4cdf-abec-b22526842898","comm_id":"8151cde2230b4a658af0d3b0e6811d83","client_comm_id":"232663e921114fefa8890e554b772c12"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"148219ff-823c-4f74-95ad-981580385bfc","roots":{"186758f4-a6c5-4cdf-abec-b22526842898":"a1a375a3-b54e-4c9f-82e3-65ac905fe045"},"root_ids":["186758f4-a6c5-4cdf-abec-b22526842898"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(version);
#     } else if (root.Bokeh.version === version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root.Tabulator !== undefined) && ( root.Tabulator !== undefined) && ( root.Tabulator !== undefined) && ( root.Tabulator !== undefined) && ( root.Tabulator !== undefined) && ( root.Tabulator !== undefined) && ( root.Tabulator !== undefined) && ( root.Tabulator !== undefined) && ( root.Tabulator !== undefined) && ( root.Plotly !== undefined) && ( root.Plotly !== undefined) && ( root.Plotly !== undefined) && ( root.Plotly !== undefined) && ( root.Plotly !== undefined) && ( root.Plotly !== undefined) && ( root.Plotly !== undefined) && ( root.Plotly !== undefined) && ( root.Plotly !== undefined) && ( root.Plotly !== undefined) && ( root.Plotly !== undefined) && ( root.Plotly !== undefined) && ( root.Plotly !== undefined) && ( root.Plotly !== undefined) && ( root.Plotly !== undefined) && ( root.Plotly !== undefined) && ( root.Plotly !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clea
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# WARNING:param.ParamFunction08482: The function 'scatter_plot' does not have any dependencies and will never update. Are you sure you did not intend to depend on or bind a parameter or widget to this function? If not simply call the function before passing it to Panel. Otherwise, when passing a parameter as an argument, ensure you pass at least one parameter and reference the actual parameter object not the current value, i.e. use object.param.parameter not object.parameter.
# WARNING:param.ParamFunction08519: The function 'stacked_bar' does not have any dependencies and will never update. Are you sure you did not intend to depend on or bind a parameter or widget to this function? If not simply call the function before passing it to Panel. Otherwise, when passing a parameter as an argument, ensure you pass at least one parameter and reference the actual parameter object not the current value, i.e. use object.param.parameter not object.parameter.
# WARNING:param.ParamFunction08553: The function 'pie_chart' does not have any dependencies and will never update. Are you sure you did not intend to depend on or bind a parameter or widget to this function? If not simply call the function before passing it to Panel. Otherwise, when passing a parameter as an argument, ensure you pass at least one parameter and reference the actual parameter object not the current value, i.e. use object.param.parameter not object.parameter.
# WARNING:param.ParamFunction08560: The function 'state_bar' does not have any dependencies and will never update. Are you sure you did not intend to depend on or bind a parameter or widget to this function? If not simply call the function before passing it to Panel. Otherwise, when passing a parameter as an argument, ensure you pass at least one parameter and reference the actual parameter object not the current value, i.e. use object.param.parameter not object.parameter.
# WARNING:param.ParamFunction08568: The function 'trend_line' does not have any dependencies and will never update. Are you sure you did not intend to depend on or bind a parameter or widget to this function? If not simply call the function before passing it to Panel. Otherwise, when passing a parameter as an argument, ensure you pass at least one parameter and reference the actual parameter object not the current value, i.e. use object.param.parameter not object.parameter.
# WARNING:param.ParamFunction08575: The function 'growth_chart' does not have any dependencies and will never update. Are you sure you did not intend to depend on or bind a parameter or widget to this function? If not simply call the function before passing it to Panel. Otherwise, when passing a parameter as an argument, ensure you pass at least one parameter and reference the actual parameter object not the current value, i.e. use object.param.parameter not object.parameter.
# Launching server at http://localhost:60026
# 2026-04-24 16:25:12.527 200 GET / (::1) 953.31ms
# 2026-04-24 16:25:12.567 200 GET /static/extensions/panel/bundled/plotlyplot/maplibre-gl@4.4.1/dist/maplibre-gl.css?v=1.8.10 (::1) 4.55ms
# 2026-04-24 16:25:12.578 200 GET /static/extensions/panel/bundled/datatabulator/tabulator-tables@6.3.1/dist/css/tabulator_simple.min.css?v=1.8.10 (::1) 5.88ms
# 2026-04-24 16:25:12.583 200 GET /static/extensions/panel/bundled/reactiveesm/es-module-shims@%5E1.10.0/dist/es-module-shims.min.js (::1) 9.82ms
# 2026-04-24 16:25:12.592 200 GET /static/extensions/panel/bundled/datatabulator/luxon/build/global/luxon.min.js (::1) 17.37ms
# 2026-04-24 16:25:12.602 200 GET /static/extensions/panel/css/loadingspinner.css?v=1.8.10 (::1) 4.62ms
# 2026-04-24 16:25:12.606 200 GET /static/extensions/panel/css/markdown.css?v=1.8.10 (::1) 7.92ms
# 2026-04-24 16:25:12.611 200 GET /static/extensions/panel/bundled/datatabulator/tabulator-tables@6.3.1/dist/js/tabulator.min.js (::1) 36.92ms
# 2026-04-24 16:25:12.624 200 GET /static/extensions/panel/css/listpanel.css?v=1.8.10 (::1) 4.60ms
# 2026-04-24 16:25:12.629 200 GET /static/extensions/panel/css/loading.css?v=1.8.10 (::1) 8.68ms
# 2026-04-24 16:25:12.634 200 GET /static/extensions/panel/bundled/theme/default.css?v=1.8.10 (::1) 12.85ms
# 2026-04-24 16:25:12.642 200 GET /static/js/bokeh.min.js?v=2630124d82b67a204b9c9da925d3d456e9ec585bb0cf8f839a1c704dbee3f200b70d237916a9fd429755022dc83ac334505cd7385ebb4453a7b17aa1d3699c35 (::1) 42.76ms
# 2026-04-24 16:25:12.647 200 GET /static/extensions/panel/css/multichoice.css?v=1.8.10 (::1) 10.39ms
# 2026-04-24 16:25:12.659 200 GET /static/extensions/panel/bundled/fastbasetemplate/fast.css?v=1.8.10 (::1) 5.28ms
# 2026-04-24 16:25:12.663 200 GET /static/extensions/panel/bundled/fastlisttemplate/fast_list_template.css?v=1.8.10 (::1) 9.06ms
# 2026-04-24 16:25:12.669 200 GET /static/js/bokeh-gl.min.js?v=b803cb051212c1e9f0fba71c62739c0cfb38114322d67a2ace60eee732710b6541d80907d9fcf0afb2f962c368f1db1e30b8800652d9510d1b801727f9669eb2 (::1) 13.92ms
# 2026-04-24 16:25:12.675 200 GET /static/js/bokeh-widgets.min.js?v=aa4c33f38bd3425dafb970d1ce795ccf91e608a9a6d4db35f85f382954d7a91abf76031394f3af6ecb919a1b5dbbfefa2734c7a543132a8f0c0f24a2f9d3237b (::1) 19.42ms
# 2026-04-24 16:25:12.681 200 GET /static/js/bokeh-tables.min.js?v=62532f6ff926a41c47def08668ee2cec06b351a8e8a5ca01a21fdc78811c3fc5d6b048deaf949f6abc5c6963b7bbf56ea285d6ada0b7a61191449d0d115bf737 (::1) 9.18ms
# 2026-04-24 16:25:12.697 200 GET /static/extensions/panel/bundled/fast/js/fast_design.js (::1) 9.35ms
# 2026-04-24 16:25:12.706 200 GET /static/extensions/panel/bundled/fastbasetemplate/fast_template.js (::1) 10.91ms
# 2026-04-24 16:25:12.715 200 GET /static/extensions/panel/bundled/plotlyplot/plotly-3.1.0.min.js (::1) 140.83ms
# 2026-04-24 16:25:12.721 200 GET /static/extensions/panel/bundled/@microsoft/fast-components@2.30.6/dist/fast-components.js (::1) 33.63ms
# 2026-04-24 16:25:12.728 200 GET /static/extensions/panel/panel.min.js?v=b081f23dfb5efd1bbe84e7fda7427a25cfc354ce9fbf1fd8e5c35899acb2b3bb (::1) 42.31ms
# 2026-04-24 16:25:12.819 200 GET /static/js/bokeh-mathjax.min.js?v=03ca8f404ba96ea2376b99248bf79a79084be396de8b5a1b95cb017567540ea3b565dcc8c0baa78446abbddeba0f2ea6bfe0cff8551bf8d9a11deb67c70a63f2 (::1) 132.46ms
# 2026-04-24 16:25:13.705 101 GET /ws (::1) 1.69ms
# 2026-04-24 16:25:13.751 200 GET /favicon.ico (::1) 1.21ms
# 2026-04-24 16:25:13.934 200 GET /static/extensions/panel/bundled/theme/fast.css?v=1.8.10 (::1) 2.97ms
