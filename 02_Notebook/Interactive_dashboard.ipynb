# %%
#!pip install hvplot 
#!pip install panel

# %%
import pandas as pd
import numpy as np
import panel as pn
pn.extension('tabulator')

import hvplot.pandas
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='f57597fe-1e29-45c0-a718-bdd902c0e19c'>
#   <div id="c016b18a-165a-453c-825e-ee3c3659a4da" data-root-id="f57597fe-1e29-45c0-a718-bdd902c0e19c" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
df = pd.read_csv("owid-co2-data.csv")

# %%
# cache data to improve dashboard performance
if 'data' not in pn.state.cache.keys():

    df = pd.read_csv('owid-co2-data.csv')

    pn.state.cache['data'] = df.copy()

else: 

    df = pn.state.cache['data']

# %%
df
# Out:
#            country  year iso_code  population           gdp  cement_co2  \
# 0      Afghanistan  1750      AFG   2802560.0           NaN       0.000
# 1      Afghanistan  1751      AFG         NaN           NaN       0.000
# 2      Afghanistan  1752      AFG         NaN           NaN       0.000
# 3      Afghanistan  1753      AFG         NaN           NaN       0.000
# 4      Afghanistan  1754      AFG         NaN           NaN       0.000
# ...            ...   ...      ...         ...           ...         ...
# 50406     Zimbabwe  2020      ZWE  15526887.0  2.317871e+10       0.496
# 50407     Zimbabwe  2021      ZWE  15797220.0  2.514009e+10       0.542
# 50408     Zimbabwe  2022      ZWE  16069061.0  2.590159e+10       0.387
# 50409     Zimbabwe  2023      ZWE  16340829.0           NaN       0.387
# 50410     Zimbabwe  2024      ZWE  16634366.0           NaN       0.387
#
#        cement_co2_per_capita     co2  co2_growth_abs  co2_growth_prct  ...  \
# ...

# %%
df[df['country'] == 'North America']
# Out:
#              country  year iso_code   population  gdp  cement_co2  \
# 33561  North America  1750      NaN   11430595.0  NaN       0.000
# 33562  North America  1751      NaN          NaN  NaN       0.000
# 33563  North America  1752      NaN          NaN  NaN       0.000
# 33564  North America  1753      NaN          NaN  NaN       0.000
# 33565  North America  1754      NaN          NaN  NaN       0.000
# ...              ...   ...      ...          ...  ...         ...
# 33831  North America  2020      NaN  598250669.0  NaN      72.889
# 33832  North America  2021      NaN  600876349.0  NaN      75.463
# 33833  North America  2022      NaN  604356255.0  NaN      74.810
# 33834  North America  2023      NaN  608770547.0  NaN      73.740
# 33835  North America  2024      NaN  613150315.0  NaN      70.584
#
#        cement_co2_per_capita       co2  co2_growth_abs  co2_growth_prct  ...  \
# 33561                  0.000       NaN             NaN              NaN  ...
# ...

# %%
df[df['country'] == 'World']
# Out:
#       country  year iso_code    population           gdp  cement_co2  \
# 49511   World  1750      NaN  7.532793e+08           NaN         NaN
# 49512   World  1751      NaN           NaN           NaN         NaN
# 49513   World  1752      NaN           NaN           NaN         NaN
# 49514   World  1753      NaN           NaN           NaN         NaN
# 49515   World  1754      NaN           NaN           NaN         NaN
# ...       ...   ...      ...           ...           ...         ...
# 49781   World  2020      NaN  7.887001e+09  1.185900e+14    1624.052
# 49782   World  2021      NaN  7.954448e+09  1.260048e+14    1666.885
# 49783   World  2022      NaN  8.021407e+09  1.301126e+14    1578.739
# 49784   World  2023      NaN  8.091735e+09           NaN    1540.286
# 49785   World  2024      NaN  8.161973e+09           NaN    1472.818
#
#        cement_co2_per_capita        co2  co2_growth_abs  co2_growth_prct  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50411 entries, 0 to 50410
# Data columns (total 79 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   country                                    50411 non-null  str
#  1   year                                       50411 non-null  int64
#  2   iso_code                                   42480 non-null  str
#  3   population                                 41167 non-null  float64
#  4   gdp                                        15251 non-null  float64
#  5   cement_co2                                 29173 non-null  float64
#  6   cement_co2_per_capita                      25648 non-null  float64
#  7   co2                                        29384 non-null  float64
#  8   co2_growth_abs                             27216 non-null  float64
#  9   co2_growth_prct                            26239 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# country                            0
# year                               0
# iso_code                        7931
# population                      9244
# gdp                            35160
#                                ...
# temperature_change_from_n2o    12131
# total_ghg                      12261
# total_ghg_excluding_lucf       12598
# trade_co2                      45699
# trade_co2_share                45699
# Length: 79, dtype: int64

# %% [markdown]
# ## (0) Some minor data preprocessing

# %%
# Fill NAs with 0s and create GDP per capita column
df = df.fillna(0)
df['gdp_per_capita'] = np.where(df['population']!= 0, df['gdp']/ df['population'], 0)

# %%
df
# Out:
#            country  year iso_code  population           gdp  cement_co2  \
# 0      Afghanistan  1750      AFG   2802560.0  0.000000e+00       0.000
# 1      Afghanistan  1751      AFG         0.0  0.000000e+00       0.000
# 2      Afghanistan  1752      AFG         0.0  0.000000e+00       0.000
# 3      Afghanistan  1753      AFG         0.0  0.000000e+00       0.000
# 4      Afghanistan  1754      AFG         0.0  0.000000e+00       0.000
# ...            ...   ...      ...         ...           ...         ...
# 50406     Zimbabwe  2020      ZWE  15526887.0  2.317871e+10       0.496
# 50407     Zimbabwe  2021      ZWE  15797220.0  2.514009e+10       0.542
# 50408     Zimbabwe  2022      ZWE  16069061.0  2.590159e+10       0.387
# 50409     Zimbabwe  2023      ZWE  16340829.0  0.000000e+00       0.387
# 50410     Zimbabwe  2024      ZWE  16634366.0  0.000000e+00       0.387
#
#        cement_co2_per_capita     co2  co2_growth_abs  co2_growth_prct  ...  \
# ...

# %%
# Make DataFrame Pipeline Interactive
idf = df.interactive()

# %% [markdown]
# ## (1) CO2 emission over time by continent

# %%
# Define Panel widgets
year_slider = pn.widgets.IntSlider(name='Year slider', start=1850, end=2026, step=5,value=1850)
year_slider
# Out:
# IntSlider(end=2026, name='Year slider', start=1850, step=5, value=1850)

# %%
# Radio buttons for CO2 measures
yaxis_co2 = pn.widgets.RadioButtonGroup(
    name='Y axis', 
    options=['co2', 'co2_per_capita',],
    button_type='success'
)
yaxis_co2
# Out:
# RadioButtonGroup(button_type='success', name='Y axis', options=['co2', 'co2_per_capita'], value='co2')

# %%
continents = ['World', 'Asia', 'Oceania', 'Europe', 'Africa', 'North America', 
              'South America', 'Antarctica']
co2_pipeline = (
    idf[
        (idf.year <= year_slider) &
        (idf.country.isin(continents))
    ]
    .groupby(['country', 'year'])[yaxis_co2].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='year')  
    .reset_index(drop=True)
)

# %%
co2_pipeline
# Out:
# <div id='9dcea8c2-f9b2-447a-91da-5386e40850f7'>
#   <div id="d0552c3f-49a7-44df-8bb1-b8407d514b9d" data-root-id="9dcea8c2-f9b2-447a-91da-5386e40850f7" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
co2_plot = co2_pipeline.hvplot(x = 'year', by='country', 
                               y=yaxis_co2,
                               line_width=2, 
                               title="CO2 emission by continent")
co2_plot
# Out:
# <div id='2ddb6f20-6826-4f5b-85fd-8e414777bc4e'>
#   <div id="a4cfdca9-a222-48a3-92b8-7b8e6b3c7f8d" data-root-id="2ddb6f20-6826-4f5b-85fd-8e414777bc4e" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# ## (2) Table - CO2 emission over time by continent

# %%
co2_table = co2_pipeline.pipe(pn.widgets.Tabulator, pagination='remote', page_size = 10, sizing_mode='stretch_width') 
co2_table
# Out:
# <div id='41abd1bf-a844-4282-b369-1ce6f7cacfab'>
#   <div id="eded2ccb-1adc-4397-8e5a-ec572eecfaad" data-root-id="41abd1bf-a844-4282-b369-1ce6f7cacfab" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# ## (3) CO2 vs GDP scatterplot

# %%
co2_vs_gdp_scatterplot_pipeline = (
    idf[
        (idf.year == year_slider) &
        (~ (idf.country.isin(continents)))
    ]
    .groupby(['country', 'year', 'gdp_per_capita'])['co2'].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='year')  
    .reset_index(drop=True)
)

# %%
co2_vs_gdp_scatterplot_pipeline
# Out:
# <div id='6abea889-c337-4bd8-a8a4-f62b924b6dd3'>
#   <div id="ea91bc90-e024-42a7-87b6-e51796111998" data-root-id="6abea889-c337-4bd8-a8a4-f62b924b6dd3" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
co2_vs_gdp_scatterplot = co2_vs_gdp_scatterplot_pipeline.hvplot(x='gdp_per_capita',y='co2', 
                        by='country',size=80, kind="scatter", alpha=0.7,
                       legend=False,height=500, width=500)
co2_vs_gdp_scatterplot
# Out:
# <div id='13b0b0db-482f-4a76-a99b-0ddf23597753'>
#   <div id="ce520515-5076-4e9e-8dc8-2298e24d4f80" data-root-id="13b0b0db-482f-4a76-a99b-0ddf23597753" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# ## (4) Bar chart with CO2 sources by continent

# %%
yaxis_co2_source = pn.widgets.RadioButtonGroup(
    name='Y axis', 
    options=['coal_co2', 'oil_co2', 'gas_co2'], 
    button_type='success'
)

continents_excl_world = ['Asia', 'Oceania', 'Europe', 'Africa', 'North America', 'South America', 'Antarctica']

co2_source_bar_pipeline = (
    idf[
        (idf.year == year_slider) &
        (idf.country.isin(continents_excl_world))
    ]
    .groupby(['year', 'country'])[yaxis_co2_source].sum()
    .to_frame()
    .reset_index()
    .sort_values(by='year')  
    .reset_index(drop=True)
)

# %%
co2_source_bar_plot = co2_source_bar_pipeline.hvplot(kind='bar', 
                        x='country',y=yaxis_co2_source, 
                        title='CO2 source by continent')
co2_source_bar_plot
# Out:
# <div id='365096b0-19e4-4b20-a48d-a28d729cb49b'>
#   <div id="fa6daad4-664e-4809-be9f-b7587f548bb6" data-root-id="365096b0-19e4-4b20-a48d-a28d729cb49b" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %% [markdown]
# ## Creating Dashboard

# %%
#12  17 18 23 31 44 47 52 


#Layout using Template
template = pn.template.FastListTemplate(
    title='World CO2 emission dashboard', 
    sidebar=[pn.pane.Markdown("# CO2 Emissions and Climate Change"), 
             pn.pane.Markdown("#### Carbon dioxide "), 
             pn.pane.PNG('climate_day.png', sizing_mode='scale_both'),
             pn.pane.Markdown("## Settings"),   
             year_slider],
    main=[pn.Row(pn.Column(yaxis_co2, 
                co2_plot.panel(width=700), margin=(0,25)), 
                co2_table.panel(width=500)), 
          pn.Row(pn.Column(co2_vs_gdp_scatterplot.panel(width=600), margin=(0,25)), pn.Column(yaxis_co2_source, co2_source_bar_plot.panel(width=600)))],
    accent_base_color="#88d8b0",
    header_background="#88d8b0",
)
template.show()
template.servable();
# Out:
# Launching server at http://localhost:59236
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='9f77e0bf-6a6c-4feb-a75a-d367a53fa37e', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='6c6c31b0-8450-4fbb-80a6-4486b6737359', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='af64c191-79cd-4aeb-998a-7bbb7ef618f6', ...)
# 2026-04-23 00:44:52,037 ERROR: panel.reactive - Callback failed for object named 'Y axis' changing property {'value': 'co2_per_capita'}
# Traceback (most recent call last):
#   File "C:\Users\Varnika Sharma\AppData\Local\Programs\Python\Python314\Lib\site-packages\panel\reactive.py", line 479, in _process_events
#     self.param.update(**self_params)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^
# ...
